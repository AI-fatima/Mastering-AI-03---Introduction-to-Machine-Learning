# %% [markdown]
# 3.1 Clustering

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.2 Dimensionality Reduction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.3 Anomaly Detection

# %% [markdown]
# ![image.png](data:image/png;base64,...)
